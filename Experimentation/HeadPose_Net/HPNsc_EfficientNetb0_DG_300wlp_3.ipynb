# %% [markdown]
# # GameFace
# HCI With Head Pose Using Computer Vision
# Practice Module: Intelligent Sensing System (ISS)
# ---
# Specifications: <br>
# Dataset - 300W-LP <br>
# Model - EfficientNetB0<br>
# Fine Tuning - 16 layers trainable, Pitch & Roll only, BatchNormalization and Dropout Layer

# %% [markdown]
# # 0. File Path & Library Setup

# %%
# Load All Necessary Packages

import os
# from google.colab import drive

import pandas as pd
import numpy as np
import pathlib
import time
import math
import random
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Activation
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import Sequence
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.nn import softmax
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications.efficientnet import EfficientNetB0

seed = 12

print("Versions of key libraries")
print("-------------------------")
print("pandas:      ", pd.__version__)
print("numpy:       ", np.__version__)
print("opencv:      ", cv2.__version__)
print("tensorflow:  ", tf.__version__)
# Out:
# Versions of key libraries
# -------------------------
# pandas:       1.3.3
# numpy:        1.19.5
# opencv:       4.5.3
# tensorflow:   2.6.0

# %%
# # Mounting to Google Drive
# drive.mount('/content/gdrive')

# # Change Working Directory
# os.chdir('/content/gdrive/My Drive/iss/prs_pm/training')

print('Working Directory: ')
# !pwd
os.getcwd()
# Out:
# Working Directory:
# 'D:\\Personal\\Education\\NUS-ISS Mtech IS\\Course Materials\\3. Intelligent Sensing Systems (ISS)\\0. Practice Module (TT)\\Source Code\\Face Pose Estimation 1'

# %% [markdown]
# # 1. Load & Prepare Dataset

# %%
# Data Directory
hp300wlpdir = os.path.join(os.getcwd(), 'Data/300W_LP_processed')

# %% [markdown]
# ## Load File Paths

# %%
# Load Image and Annotation File Paths
data_list = [hp300wlpdir]

data_count = []
img_list = []
eur_list = []

for i in range(len(data_list)):
    data_path = os.path.join(os.getcwd(), data_list[i])
    data_folder = os.listdir(data_list[i])
    curr_data_count = 0
    for j in range(len(data_folder)):
        path = os.path.join(data_path, data_folder[j])
        file_list = os.listdir(path)
        for file in file_list:
            if file.endswith('.jpg'):
                img_path = os.path.join(path, file)
                eur_path = img_path.replace('_rgb.jpg', '_euler.txt')
                img_list.append(img_path)
                eur_list.append(eur_path)
                curr_data_count += 1
    data_count.append(curr_data_count)

print('Total number of image file Loaded: ' + str(len(img_list)))
print('Total number of label file Loaded: ' + str(len(eur_list)))
# Out:
# Total number of image file Loaded: 122450
# Total number of label file Loaded: 122450

# %% [markdown]
# ## Train Test Split Index

# %%
# Generate Train Index
        
train_idx, test_idx = train_test_split(range(len(img_list)), test_size=0.3, random_state=seed, shuffle=True)
    
print('Total train samples :', str(len(train_idx)))
print('Total test samples  :', str(len(test_idx)))
# Out:
# Total train samples : 85715
# Total test samples  : 36735

# %% [markdown]
# # 2. Model Architecture

# %% [markdown]
# ## Parameters Setup

# %% [markdown]
# ## Model Class

# %%
## Define Data Generator
class data_gen(Sequence):
    def __init__(self, img_path, eur_path, index_list, batch_size=50, resize_nrow=224, resize_nclm=224, channel=3, shuffle=True):
        self.img_path    = img_path
        self.eur_path    = eur_path
        self.index_list  = index_list
        self.batch_size  = batch_size
        self.resize_nrow = resize_nrow
        self.resize_nclm = resize_nclm
        self.channel     = channel
        self.shuffle     = shuffle
        self.on_epoch_end()
    
    def __len__(self):
        return int(len(self.index_list)/self.batch_size)
    
    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size : (index+1)*self.batch_size]
        batch_index_list = [self.index_list[k] for k in indexes]
        X = self.__load_image(batch_index_list)
        y = self.__load_euler(batch_index_list)
        return X,y
        
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.index_list))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
    
    def __load_image(self, index_list):
        dim = (self.resize_nrow, self.resize_nclm)
        X = np.empty((self.batch_size, *dim, self.channel))
        for i in range(len(index_list)):
            load_img = cv2.imread(self.img_path[index_list[i]])
            img      = cv2.resize(load_img, (self.resize_nclm, self.resize_nrow))
            X[i, ]   = img
        return X
    
    def __load_euler(self, index_list):
        y = {'Pitch': np.empty((self.batch_size)), 'Roll': np.empty((self.batch_size))}
        for i in range(len(index_list)):
            load_eur = open(self.eur_path[index_list[i]], 'r')
            eulers = np.array(load_eur.readlines()[0].split(','), dtype=np.float32)
            load_eur.close()
            y['Pitch'][i] = eulers[0]
            # y['Yaw'][i] = eulers[1]
            y['Roll'][i] = eulers[2]
        return y

# Define Custom Loss Function
class custom_loss(tf.keras.losses.Loss):
    def __init__(self, nbins=66, angle_range=99, alpha=1, name='custom_loss'):
        super().__init__(name=name)
        self.nbins = nbins
        self.angle_range = angle_range
        self.degree = 2 * angle_range / 66
        self.alpha = alpha
        self.bin_index = np.array([idx for idx in range(self.nbins)], dtype=np.float32)
        self.bin_lowerbound = tf.cast(tf.range(angle_range, angle_range, self.degree), tf.float32)
        
    def call(self, y_true, y_pred):
        # Calculate Class Loss
        cls_loss_fn = tf.keras.losses.CategoricalCrossentropy()
        cls_true = tf.one_hot(tf.searchsorted(self.bin_lowerbound, y_true[:, 0]), self.nbins)
        cls_loss = cls_loss_fn(cls_true, y_pred)
        
        # Calculate MSE Loss
        mse_loss_fn = tf.keras.losses.MeanSquaredError()
        eur_pred = tf.reduce_sum(tf.nn.softmax(y_pred) * self.bin_index, axis=1) * self.degree - self.angle_range
        mse_loss = mse_loss_fn(y_true, eur_pred)
        
        # Total Loss
        total_loss = cls_loss + self.alpha * mse_loss
        
        return total_loss

    
# Define Feature Extractor Layers
class FeatureExtractor(tf.keras.layers.Layer):
    def __init__(self, input_shape=(224, 224, 3), dropout_rate=0.2, num_trainable_layers=None):
        super(FeatureExtractor, self).__init__()
        
        # Define Feature Extractor Model without Dense(Classification) Layers
        self.feature_extractor = EfficientNetB0(include_top=False, input_shape=input_shape, drop_connect_rate=dropout_rate)
        
        # Set Trainable Weights
        if num_trainable_layers is None:
            for layer in self.feature_extractor.layers:
                layer.trainable = False
        else:
            for layer in self.feature_extractor.layers[:-num_trainable_layers]:
                layer.trainable = False
            for layer in self.feature_extractor.layers[-num_trainable_layers:]:
                # print(layer.name)
                if isinstance(layer, BatchNormalization):
                    layer.trainable = False

        
    def call(self, inputs):
        return self.feature_extractor(inputs)

# Define Model Architecture
class HeadPoseNet(tf.keras.Model):
    
    def __init__(self, input_shape=(224,224,3), nbins=66, modelname='HeadPoseNet', num_trainable_layers=None, **kwargs):
        super(HeadPoseNet, self).__init__()
        self.modelname         = modelname
        self.raw_shape         = input_shape
        self.feature_extractor = FeatureExtractor(input_shape, 0.5, num_trainable_layers)

        self.merge             = GlobalAveragePooling2D(name='Pooling')
        self.bn                = BatchNormalization(name='BatchNorm')
        self.drop              = Dropout(0.5, name='Dropout')
        
        self.pitch_euler       = Dense(units=nbins, name='Pitch_Output')
        self.roll_euler        = Dense(units=nbins, name='Roll_Output')
        self.feature_extractor._name = 'EfficientNetB0'
        
    def call(self, input_tensor):
        x = self.feature_extractor(input_tensor)
        x = self.merge(x)
        x = self.bn(x)
        x = self.drop(x)
        
        pitch     = self.pitch_euler(x)
        roll      = self.roll_euler(x)
        
        return {'Pitch':pitch, 'Roll':roll}
        
    def build_graph(self):
        x = tf.keras.layers.Input(shape=self.raw_shape, name='Input')
        return Model(inputs=x, outputs=self.call(x), name=self.modelname)

# %% [markdown]
# ## Initialization

# %%
# Head Pose Model Parameters
nbins = 66
angle_range = 99
input_width = 224
input_height = 224
channel = 3

# Model Initialization
model_name = 'HPN_EfficientNetB0_FT_16lyr_v1'
img_shape  = (input_height, input_width, 3)
hpn        = HeadPoseNet(input_shape=img_shape, nbins=nbins, modelname=model_name, num_trainable_layers=16)
hpn_go     = HeadPoseNet(input_shape=img_shape, nbins=nbins, modelname=model_name, num_trainable_layers=16)


# Model Compile
losses = {'Pitch': custom_loss(nbins=nbins, angle_range=angle_range, alpha=1),
          'Roll': custom_loss(nbins=nbins, angle_range=angle_range, alpha=1)}
optmz  = tf.keras.optimizers.RMSprop()
hpn.compile(loss=losses, optimizer=optmz)
hpn.build_graph()
hpn_go.compile(loss=losses, optimizer=optmz)
hpn_go.build_graph()

# Filepaths for callbacks
weight_path = pathlib.Path('Training\\weight')
weight_path.mkdir(parents=True, exist_ok=True) 
weight_file = os.path.join(weight_path, model_name + ".hdf5")
log_path    = pathlib.Path('Training\\log')
log_path.mkdir(parents=True, exist_ok=True) 
log_file    = os.path.join(log_path, model_name + '.csv')

# Checkpoint
checkpoint      = ModelCheckpoint(weight_file, 
                                  monitor           = 'val_loss',
                                  mode              = 'min',
                                  save_weights_only = True,
                                  save_best_only    = True,
                                  verbose           = 0)
# Training Logger
csv_logger      = CSVLogger(log_file)   

def lrSchedule(epoch):
    lr = 1e-4
    if epoch > 15:
        lr = 5e-5
    if epoch > 35:
        lr = 1e-5
    if epoch > 80:
        lr = 8e-5
    print('Learning rate: ', lr)
    return lr
LRScheduler = LearningRateScheduler(lrSchedule)

# Model Callback Lists
callbacks_list  = [checkpoint, csv_logger, LRScheduler]                                     

# Model Setup Summary
hpn.build_graph().summary()
print("Path to model :", weight_file)
print("Path to log   :", log_file)
# Out:
# Model: "HPN_EfficientNetB0_FT_16lyr_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# EfficientNetB0 (FeatureExtracto (None, 7, 7, 1280)   4049571     Input[0][0]
# __________________________________________________________________________________________________
# Pooling (GlobalAveragePooling2D (None, 1280)         0           EfficientNetB0[1][0]
# __________________________________________________________________________________________________
# BatchNorm (BatchNormalization)  (None, 1280)         5120        Pooling[1][0]
# __________________________________________________________________________________________________
# Dropout (Dropout)               (None, 1280)         0           BatchNorm[1][0]
# __________________________________________________________________________________________________
# Pitch_Output (Dense)            (None, 66)           84546       Dropout[1][0]
# __________________________________________________________________________________________________
# Roll_Output (Dense)             (None, 66)           84546       Dropout[1][0]
# ==================================================================================================
# Total params: 4,223,783
# Trainable params: 1,293,236
# Non-trainable params: 2,930,547
# __________________________________________________________________________________________________
# Path to model : Training\weight\HPN_EfficientNetB0_FT_16lyr_v1.hdf5
# Path to log   : Training\log\HPN_EfficientNetB0_FT_16lyr_v1.csv

# %% [markdown]
# ## Model Fitting

# %%
# Training Parameters
num_epoch = 50
batch_size = 50
shuffle = True

# Initialize Data Generators
train_data = data_gen(img_list, eur_list, train_idx, batch_size=batch_size, resize_nrow=input_height, resize_nclm=input_width, shuffle=shuffle)
test_data = data_gen(img_list, eur_list, test_idx, batch_size=batch_size, resize_nrow=input_height, resize_nclm=input_width, shuffle=shuffle)

st = time.time()
# Train Model
hpn_fit = hpn.fit(train_data, validation_data=test_data, epochs=num_epoch, callbacks=callbacks_list)

time_taken = round((time.time() - st)/60,2)

print('Total training time : {0:0.2f} minutes'.format(time_taken))
# Out:
# Epoch 1/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 207s 118ms/step - loss: 345.4996 - Pitch_loss: 158.9673 - Roll_loss: 186.5319 - val_loss: 226.6214 - val_Pitch_loss: 77.6063 - val_Roll_loss: 149.0153
# Epoch 2/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 198s 116ms/step - loss: 240.8574 - Pitch_loss: 92.4375 - Roll_loss: 148.4201 - val_loss: 188.2377 - val_Pitch_loss: 63.3715 - val_Roll_loss: 124.8661
# Epoch 3/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 194s 113ms/step - loss: 205.1762 - Pitch_loss: 83.0609 - Roll_loss: 122.1152 - val_loss: 146.8258 - val_Pitch_loss: 59.2046 - val_Roll_loss: 87.6212
# Epoch 4/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 195s 114ms/step - loss: 177.1755 - Pitch_loss: 77.8165 - Roll_loss: 99.3590 - val_loss: 125.5759 - val_Pitch_loss: 57.2790 - val_Roll_loss: 68.2968
# Epoch 5/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 185s 108ms/step - loss: 158.9538 - Pitch_loss: 74.2727 - Roll_loss: 84.6810 - val_loss: 117.3083 - val_Pitch_loss: 56.1053 - val_Roll_loss: 61.2030
# Epoch 6/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 198s 115ms/step - loss: 148.4910 - Pitch_loss: 71.5744 - Roll_loss: 76.9165 - val_loss: 113.8034 - val_Pitch_loss: 58.0986 - val_Roll_loss: 55.7049
# Epoch 7/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 182s 106ms/step - loss: 141.9197 - Pitch_loss: 69.8077 - Roll_loss: 72.1121 - val_loss: 109.0442 - val_Pitch_loss: 55.3970 - val_Roll_loss: 53.6471
# Epoch 8/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 207s 121ms/step - loss: 137.1581 - Pitch_loss: 67.6234 - Roll_loss: 69.5348 - val_loss: 108.1479 - val_Pitch_loss: 56.0787 - val_Roll_loss: 52.0692
# Epoch 9/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 192s 112ms/step - loss: 133.5543 - Pitch_loss: 66.7600 - Roll_loss: 66.7942 - val_loss: 103.9999 - val_Pitch_loss: 53.2942 - val_Roll_loss: 50.7057- ETA: 5s - los - ETA: 0s - loss: 133.5345 - Pitch_loss: 66.7589 - Roll_l
# Epoch 10/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 201s 117ms/step - loss: 130.5396 - Pitch_loss: 65.7071 - Roll_loss: 64.8324 - val_loss: 105.0020 - val_Pitch_loss: 54.7041 - val_Roll_loss: 50.2980
# Epoch 11/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 190s 111ms/step - loss: 127.8748 - Pitch_loss: 64.6779 - Roll_loss: 63.1967 - val_loss: 102.3709 - val_Pitch_loss: 52.8811 - val_Roll_loss: 49.4899
# Epoch 12/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 206s 120ms/step - loss: 124.7784 - Pitch_loss: 63.3585 - Roll_loss: 61.4199 - val_loss: 100.2027 - val_Pitch_loss: 51.9767 - val_Roll_loss: 48.2261
# Epoch 13/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 206s 120ms/step - loss: 121.7999 - Pitch_loss: 62.2316 - Roll_loss: 59.5684 - val_loss: 102.5746 - val_Pitch_loss: 51.3042 - val_Roll_loss: 51.2703
# Epoch 14/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 229s 133ms/step - loss: 119.1396 - Pitch_loss: 61.3873 - Roll_loss: 57.7524 - val_loss: 97.8197 - val_Pitch_loss: 51.0299 - val_Roll_loss: 46.7897
# Epoch 15/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 219s 128ms/step - loss: 116.6952 - Pitch_loss: 60.0389 - Roll_loss: 56.6562 - val_loss: 100.0017 - val_Pitch_loss: 52.1867 - val_Roll_loss: 47.8151
# Epoch 16/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 191s 112ms/step - loss: 113.9373 - Pitch_loss: 58.8111 - Roll_loss: 55.1264 - val_loss: 95.5955 - val_Pitch_loss: 49.7028 - val_Roll_loss: 45.8927
# Epoch 17/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 184s 108ms/step - loss: 109.5961 - Pitch_loss: 56.7757 - Roll_loss: 52.8204 - val_loss: 95.6008 - val_Pitch_loss: 50.1223 - val_Roll_loss: 45.4784
# Epoch 18/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 186s 109ms/step - loss: 107.9935 - Pitch_loss: 56.0034 - Roll_loss: 51.9901 - val_loss: 97.8456 - val_Pitch_loss: 50.1003 - val_Roll_loss: 47.7454
# Epoch 19/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 195s 114ms/step - loss: 106.3868 - Pitch_loss: 55.2773 - Roll_loss: 51.1095 - val_loss: 94.1815 - val_Pitch_loss: 48.9502 - val_Roll_loss: 45.2314
# Epoch 20/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 206s 120ms/step - loss: 104.9944 - Pitch_loss: 54.3319 - Roll_loss: 50.6626 - val_loss: 95.3508 - val_Pitch_loss: 48.9463 - val_Roll_loss: 46.4045
# Epoch 21/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 200s 117ms/step - loss: 104.0396 - Pitch_loss: 54.0162 - Roll_loss: 50.0234 - val_loss: 94.6749 - val_Pitch_loss: 49.6841 - val_Roll_loss: 44.9908
# Epoch 22/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 205s 120ms/step - loss: 101.7598 - Pitch_loss: 52.8923 - Roll_loss: 48.8675 - val_loss: 94.5619 - val_Pitch_loss: 49.1531 - val_Roll_loss: 45.4088
# Epoch 23/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 195s 114ms/step - loss: 100.7904 - Pitch_loss: 52.2482 - Roll_loss: 48.5422 - val_loss: 94.2553 - val_Pitch_loss: 49.0111 - val_Roll_loss: 45.2443
# Epoch 24/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 207s 121ms/step - loss: 98.9875 - Pitch_loss: 51.5469 - Roll_loss: 47.4406 - val_loss: 92.6176 - val_Pitch_loss: 48.1643 - val_Roll_loss: 44.4533
# Epoch 25/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 208s 121ms/step - loss: 98.1686 - Pitch_loss: 50.9784 - Roll_loss: 47.1902 - val_loss: 93.1163 - val_Pitch_loss: 48.3736 - val_Roll_loss: 44.7427
# Epoch 26/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 184s 107ms/step - loss: 97.1556 - Pitch_loss: 50.8493 - Roll_loss: 46.3063 - val_loss: 89.7502 - val_Pitch_loss: 46.4587 - val_Roll_loss: 43.2915
# Epoch 27/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 185s 108ms/step - loss: 96.1880 - Pitch_loss: 49.7888 - Roll_loss: 46.3994 - val_loss: 91.7971 - val_Pitch_loss: 47.6960 - val_Roll_loss: 44.1011- Pitch_loss: 49.6697 - Roll_loss: 46. - ETA: 1s - loss: 96.0353 - Pitch_loss: 49.7
# Epoch 28/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 228s 133ms/step - loss: 95.3793 - Pitch_loss: 49.3754 - Roll_loss: 46.0039 - val_loss: 89.5814 - val_Pitch_loss: 46.4519 - val_Roll_loss: 43.1294
# Epoch 29/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 213s 124ms/step - loss: 94.6861 - Pitch_loss: 49.2106 - Roll_loss: 45.4755 - val_loss: 89.4699 - val_Pitch_loss: 46.3983 - val_Roll_loss: 43.0715
# Epoch 30/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 217s 127ms/step - loss: 93.5433 - Pitch_loss: 48.4265 - Roll_loss: 45.1166 - val_loss: 90.9326 - val_Pitch_loss: 47.4530 - val_Roll_loss: 43.4798
# Epoch 31/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 210s 123ms/step - loss: 91.8403 - Pitch_loss: 47.6292 - Roll_loss: 44.2111 - val_loss: 89.7231 - val_Pitch_loss: 46.5205 - val_Roll_loss: 43.2025
# Epoch 32/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 213s 124ms/step - loss: 91.9183 - Pitch_loss: 47.5332 - Roll_loss: 44.3850 - val_loss: 89.6054 - val_Pitch_loss: 46.6453 - val_Roll_loss: 42.9601
# Epoch 33/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 207s 121ms/step - loss: 90.7679 - Pitch_loss: 46.9887 - Roll_loss: 43.7792 - val_loss: 92.3506 - val_Pitch_loss: 47.6018 - val_Roll_loss: 44.748946.9531 - Roll - ETA: 8s - loss: 90.8996 - Pitch_loss: 47. - ETA: 5s - loss: 91.0217 - Pitch_loss: 47.0989 - Roll_loss: 4 - ETA: 5s - loss: 90.9758 - Pitch_l - ETA: 2s - loss: 90.7892 - Pitch_loss:
# Epoch 34/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 215s 126ms/step - loss: 90.8224 - Pitch_loss: 46.6881 - Roll_loss: 44.1343 - val_loss: 89.7165 - val_Pitch_loss: 46.4388 - val_Roll_loss: 43.2777: 46.5588  - ETA: 2s - loss: 90.6754 - Pitch_loss: 46.6339 - Roll_loss: 44.04 - ETA: 2s - loss: 90.6404 - Pitch_loss: 46
# Epoch 35/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 216s 126ms/step - loss: 89.5154 - Pitch_loss: 46.2506 - Roll_loss: 43.2648 - val_loss: 94.8743 - val_Pitch_loss: 49.3498 - val_Roll_loss: 45.5245
# Epoch 36/50
# Learning rate:  5e-05
# 1714/1714 [==============================] - 210s 123ms/step - loss: 89.4137 - Pitch_loss: 46.2888 - Roll_loss: 43.1250 - val_loss: 87.9930 - val_Pitch_loss: 45.8984 - val_Roll_loss: 42.0947
# Epoch 37/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 222s 130ms/step - loss: 86.8687 - Pitch_loss: 44.7902 - Roll_loss: 42.0785 - val_loss: 90.2061 - val_Pitch_loss: 46.9502 - val_Roll_loss: 43.2559
# Epoch 38/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 188s 109ms/step - loss: 86.8885 - Pitch_loss: 44.7082 - Roll_loss: 42.1803 - val_loss: 89.9434 - val_Pitch_loss: 46.8517 - val_Roll_loss: 43.0917
# Epoch 39/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 184s 107ms/step - loss: 85.8290 - Pitch_loss: 44.3086 - Roll_loss: 41.5205 - val_loss: 89.3139 - val_Pitch_loss: 46.4140 - val_Roll_loss: 42.9000: 44.4943
# Epoch 40/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 203s 119ms/step - loss: 85.7067 - Pitch_loss: 43.9691 - Roll_loss: 41.7375 - val_loss: 89.3102 - val_Pitch_loss: 46.2784 - val_Roll_loss: 43.0318
# Epoch 41/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 182s 106ms/step - loss: 85.5180 - Pitch_loss: 44.1457 - Roll_loss: 41.3723 - val_loss: 90.0485 - val_Pitch_loss: 46.7526 - val_Roll_loss: 43.2958
# Epoch 42/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 207s 121ms/step - loss: 85.5478 - Pitch_loss: 43.9290 - Roll_loss: 41.6189 - val_loss: 89.7880 - val_Pitch_loss: 46.5487 - val_Roll_loss: 43.2393
# Epoch 43/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 202s 118ms/step - loss: 85.2783 - Pitch_loss: 43.7550 - Roll_loss: 41.5232 - val_loss: 88.9348 - val_Pitch_loss: 46.1187 - val_Roll_loss: 42.8161
# Epoch 44/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 205s 119ms/step - loss: 84.9295 - Pitch_loss: 43.6188 - Roll_loss: 41.3107 - val_loss: 89.0232 - val_Pitch_loss: 46.1296 - val_Roll_loss: 42.8937
# Epoch 45/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 215s 126ms/step - loss: 84.9526 - Pitch_loss: 43.7755 - Roll_loss: 41.1771 - val_loss: 88.2792 - val_Pitch_loss: 45.6647 - val_Roll_loss: 42.6146
# Epoch 46/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 213s 124ms/step - loss: 84.7205 - Pitch_loss: 43.5538 - Roll_loss: 41.1666 - val_loss: 88.4498 - val_Pitch_loss: 45.9527 - val_Roll_loss: 42.4971
# Epoch 47/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 217s 126ms/step - loss: 85.2192 - Pitch_loss: 43.7916 - Roll_loss: 41.4278 - val_loss: 88.3099 - val_Pitch_loss: 45.7114 - val_Roll_loss: 42.5986
# Epoch 48/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 210s 122ms/step - loss: 84.2457 - Pitch_loss: 43.2531 - Roll_loss: 40.9927 - val_loss: 88.5623 - val_Pitch_loss: 45.8266 - val_Roll_loss: 42.7356
# Epoch 49/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 214s 125ms/step - loss: 84.1366 - Pitch_loss: 43.3718 - Roll_loss: 40.7647 - val_loss: 89.0151 - val_Pitch_loss: 46.1373 - val_Roll_loss: 42.8778
# Epoch 50/50
# Learning rate:  1e-05
# 1714/1714 [==============================] - 210s 122ms/step - loss: 83.7021 - Pitch_loss: 42.9091 - Roll_loss: 40.7931 - val_loss: 89.6407 - val_Pitch_loss: 46.5098 - val_Roll_loss: 43.1309
# Total training time : 169.47 minutes

# %% [markdown]
# ## Model Saving

# %%
# SavedModel Path
model_path = pathlib.Path('Training/model')
model_path.mkdir(parents=True, exist_ok=True)
save_model_name = 'HPN_EfficientNetB0_FT_16lyr_v1'
model_file = os.path.join(model_path, save_model_name)

# Save Model Architecture and Weights to File
hpn_go.compile(loss=losses, optimizer=optmz)
hpn_go.compute_output_shape(input_shape=(None, *img_shape))
hpn_go.load_weights(weight_file)
hpn_go.save(model_file, save_format='tf')
# Out:
# INFO:tensorflow:Assets written to: Training\model\HPN_EfficientNetB0_FT_16lyr_v2\assets
# C:\Users\JMLim\anaconda3\envs\py39_gpu1\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %% [markdown]
# # 3. Model Evaluation

# %% [markdown]
# ## Loss Chart

# %%
# Model Evaluation
hpn_result = pd.DataFrame(hpn_fit.history)

plt.figure(figsize=(27,6))
# Plot Train and Validation Loss
plt.subplot(121)
plt.plot(hpn_result['loss'])
plt.plot(hpn_result['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model Loss')
plt.legend(['train', 'validation'], loc='upper left')

# %% [markdown]
# ## Load Model

# %%
# SavedModel Path
model_path = pathlib.Path('Training/model')
model_path.mkdir(parents=True, exist_ok=True)
load_model_name = 'HPN_EfficientNetB0_FT_16lyr_v1'
model_file = os.path.join(model_path, load_model_name)

# Load Model Architecture and Weights
hpn_go.compile(loss=losses, optimizer=optmz)
hpn_go.compute_output_shape(input_shape=(None, *img_shape))
hpn_go.load_weights(weight_file)

# %% [markdown]
# ## Prediction Function

# %%
# Function to predict euler bins
def hpn_predict_bins(loaded_model, input_tensor):
    pred_bins = loaded_model(input_tensor)
    return pred_bins['Pitch'], pred_bins['Roll']

# Function to calculate predict angle
@tf.function
def derive_eur(pred_bins, bin_index, bin_degree, angle_range):
    pred_eur = tf.reduce_sum(tf.nn.softmax(pred_bins) * bin_index, axis=1) * bin_degree - angle_range
    return pred_eur
    
# Function to calculate total square error (TSE)
@tf.function
def cal_TSE(y_true, y_pred):
    TSE = tf.reduce_sum((y_true - y_pred) ** 2)
    return TSE

# Function to calculate total absolute error (TAE)
@tf.function
def cal_TAE(y_true, y_pred):
    TAE = tf.reduce_sum(tf.math.abs(y_true - y_pred))
    return TAE

# %% [markdown]
# ## Calculate MSE & MAE

# %%
# Initialization
input_width = 224
input_height = 224

count = 0
batch_count = 100

pitch_TSE = 0
roll_TSE = 0

pitch_TAE = 0
roll_TAE = 0

bin_index = np.array([idx for idx in range(nbins)], dtype=np.float32)
bin_degree = 2 * angle_range / nbins

num_batch = len(test_idx) // batch_count + 1
last_batch_size = len(test_idx) % batch_count

# Load and Calculate Squared Error by batch
for i in range(num_batch):
    batch_idx = np.array(test_idx[i*batch_count : min((i+1)*batch_count, len(test_idx))])
    batch_img_list = np.array(img_list)[batch_idx]
    batch_eur_list = np.array(eur_list)[batch_idx]
    
    batch_img_data = []
    batch_eur_data = []
    # Load image and euler angles
    for i in range(len(batch_idx)):
        # Load image
        img_path = batch_img_list[i]
        load_img = cv2.imread(img_path)
        img = cv2.resize(load_img, (input_width, input_height))
        # Load euler angles
        eur_path = batch_eur_list[i]
        eur_file = open(eur_path, 'r')
        eur = np.array(eur_file.readlines()[0].split(','), dtype=np.float32)[[0,2]] # Only take pitch and roll
        eur_file.close()
        # Appends
        batch_img_data.append(img)
        batch_eur_data.append(eur)
    
    batch_img_data = np.array(batch_img_data)
    batch_eur_data = np.array(batch_eur_data)
    # Bin Prediction
    pitch_bins, roll_bins = hpn_predict_bins(hpn_go, batch_img_data)
    
    # Euler Prediction
    pitch_eur = derive_eur(pitch_bins, bin_index, bin_degree, angle_range)
    roll_eur  = derive_eur(roll_bins, bin_index, bin_degree, angle_range)
    
    # Calculate TSE
    batch_pitch_TSE = cal_TSE(batch_eur_data[:,0], pitch_eur)
    batch_roll_TSE = cal_TSE(batch_eur_data[:,1], roll_eur)
    
    # Calculate TAE
    batch_pitch_TAE = cal_TAE(batch_eur_data[:,0], pitch_eur)
    batch_roll_TAE = cal_TAE(batch_eur_data[:,1], roll_eur)
    
    # Append Results
    pitch_TSE += batch_pitch_TSE
    roll_TSE  += batch_roll_TSE
    pitch_TAE += batch_pitch_TAE
    roll_TAE  += batch_roll_TAE
    count     += len(batch_idx)

# Calculate final Stats
pitch_MSE = pitch_TSE.numpy() / count
roll_MSE  = roll_TSE.numpy() / count
pitch_MAE = pitch_TAE.numpy() / count
roll_MAE  = roll_TAE.numpy() / count
avg_MSE   = (pitch_MSE + roll_MSE)/2
avg_MAE   = (pitch_MAE + roll_MAE)/2

print('==========================================================================')
print('Individual Euler Angle Mean Squared Error (MSE):')
print('------------------------------------------------')
print('Pitch MSE :', str(round(pitch_MSE,3)))
print('Roll MSE  :', str(round(roll_MSE,3)))
print('==========================================================================')
print('Individual Euler Angle Mean Absolute Error (MAE):')
print('------------------------------------------------')
print('Pitch MAE :', str(round(pitch_MAE,3)))
print('Roll MAE  :', str(round(roll_MAE,3)))
print('==========================================================================')
print('Overall MSE & MAE:')
print('------------------------------------------------')
print('MSE :', str(round(avg_MSE,3)))
print('MAE :', str(round(avg_MAE,3)))
# Out:
# ==========================================================================
# Individual Euler Angle Mean Squared Error (MSE):
# ------------------------------------------------
# Pitch MSE : 30.269
# Roll MSE  : 26.676
# ==========================================================================
# Individual Euler Angle Mean Absolute Error (MAE):
# ------------------------------------------------
# Pitch MAE : 3.021
# Roll MAE  : 2.585
# ==========================================================================
# Overall MSE & MAE:
# ------------------------------------------------
# MSE : 28.472
# MAE : 2.803
