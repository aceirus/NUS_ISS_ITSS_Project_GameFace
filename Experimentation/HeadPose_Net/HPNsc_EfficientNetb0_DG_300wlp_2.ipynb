# %% [markdown]
# # GameFace
# HCI With Head Pose Using Computer Vision
# Practice Module: Intelligent Sensing System (ISS)
# ---
# Specifications: <br>
# Dataset - 300W-LP<br>
# Model - EfficientNetB0<br>
# Fine Tuning - 16 layers trainable <br>

# %% [markdown]
# # 0. File Path & Library Setup

# %%
# Load All Necessary Packages

import os
# from google.colab import drive

import pandas as pd
import numpy as np
import pathlib
import time
import math
import random
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Activation
from tensorflow.keras import optimizers
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import Sequence
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.nn import softmax
from tensorflow.keras.optimizers import Adam

from tensorflow.keras.applications.efficientnet import EfficientNetB0

seed = 12

print("Versions of key libraries")
print("-------------------------")
print("pandas:      ", pd.__version__)
print("numpy:       ", np.__version__)
print("opencv:      ", cv2.__version__)
print("tensorflow:  ", tf.__version__)
# Out:
# Versions of key libraries
# -------------------------
# pandas:       1.3.3
# numpy:        1.19.5
# opencv:       4.5.3
# tensorflow:   2.6.0

# %%
# # Mounting to Google Drive
# drive.mount('/content/gdrive')

# # Change Working Directory
# os.chdir('/content/gdrive/My Drive/iss/prs_pm/training')

print('Working Directory: ')
# !pwd
os.getcwd()
# Out:
# Working Directory:
# 'D:\\Personal\\Education\\NUS-ISS Mtech IS\\Course Materials\\3. Intelligent Sensing Systems (ISS)\\0. Practice Module (TT)\\Source Code\\Face Pose Estimation 1'

# %% [markdown]
# # 1. Load & Prepare Dataset

# %%
# Data Directory
hp300wlpdir = os.path.join(os.getcwd(), 'Data/300W_LP_processed')

# %% [markdown]
# ## Load File Paths

# %%
# Load Image and Annotation File Paths
data_list = [hp300wlpdir]

data_count = []
img_list = []
eur_list = []

for i in range(len(data_list)):
    data_path = os.path.join(os.getcwd(), data_list[i])
    data_folder = os.listdir(data_list[i])
    curr_data_count = 0
    for j in range(len(data_folder)):
        path = os.path.join(data_path, data_folder[j])
        file_list = os.listdir(path)
        for file in file_list:
            if file.endswith('.jpg'):
                img_path = os.path.join(path, file)
                eur_path = img_path.replace('_rgb.jpg', '_euler.txt')
                img_list.append(img_path)
                eur_list.append(eur_path)
                curr_data_count += 1
    data_count.append(curr_data_count)

print('Total number of image file Loaded: ' + str(len(img_list)))
print('Total number of label file Loaded: ' + str(len(eur_list)))
# Out:
# Total number of image file Loaded: 122450
# Total number of label file Loaded: 122450

# %% [markdown]
# ## Train Test Split Index

# %%
# Generate Train Index
        
train_idx, test_idx = train_test_split(range(len(img_list)), test_size=0.3, random_state=seed, shuffle=True)
    
print('Total train samples :', str(len(train_idx)))
print('Total test samples  :', str(len(test_idx)))
# Out:
# Total train samples : 85715
# Total test samples  : 36735

# %% [markdown]
# # 2. Model Architecture

# %% [markdown]
# ## Parameters Setup

# %% [markdown]
# ## Model Class

# %%
## Define Data Generator
class data_gen(Sequence):
    def __init__(self, img_path, eur_path, index_list, batch_size=50, resize_nrow=224, resize_nclm=224, channel=3, shuffle=True):
        self.img_path    = img_path
        self.eur_path    = eur_path
        self.index_list  = index_list
        self.batch_size  = batch_size
        self.resize_nrow = resize_nrow
        self.resize_nclm = resize_nclm
        self.channel     = channel
        self.shuffle     = shuffle
        self.on_epoch_end()
    
    def __len__(self):
        return int(len(self.index_list)/self.batch_size)
    
    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size : (index+1)*self.batch_size]
        batch_index_list = [self.index_list[k] for k in indexes]
        X = self.__load_image(batch_index_list)
        y = self.__load_euler(batch_index_list)
        return X,y
        
    def on_epoch_end(self):
        self.indexes = np.arange(len(self.index_list))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
    
    def __load_image(self, index_list):
        dim = (self.resize_nrow, self.resize_nclm)
        X = np.empty((self.batch_size, *dim, self.channel))
        for i in range(len(index_list)):
            load_img = cv2.imread(self.img_path[index_list[i]])
            img      = cv2.resize(load_img, (self.resize_nclm, self.resize_nrow))
            X[i, ]   = img
        return X
    
    def __load_euler(self, index_list):
        y = {'Pitch': np.empty((self.batch_size)), 'Yaw': np.empty((self.batch_size)), 'Roll': np.empty((self.batch_size))}
        for i in range(len(index_list)):
            load_eur = open(self.eur_path[index_list[i]], 'r')
            eulers = np.array(load_eur.readlines()[0].split(','), dtype=np.float32)
            load_eur.close()
            y['Pitch'][i] = eulers[0]
            y['Yaw'][i] = eulers[1]
            y['Roll'][i] = eulers[2]
        return y

# Define Custom Loss Function
class custom_loss(tf.keras.losses.Loss):
    def __init__(self, nbins=66, angle_range=99, alpha=1, name='custom_loss'):
        super().__init__(name=name)
        self.nbins = nbins
        self.angle_range = angle_range
        self.degree = 2 * angle_range / 66
        self.alpha = alpha
        self.bin_index = np.array([idx for idx in range(self.nbins)], dtype=np.float32)
        self.bin_lowerbound = tf.cast(tf.range(angle_range, angle_range, self.degree), tf.float32)
        
    def call(self, y_true, y_pred):
        # Calculate Class Loss
        cls_loss_fn = tf.keras.losses.CategoricalCrossentropy()
        cls_true = tf.one_hot(tf.searchsorted(self.bin_lowerbound, y_true[:, 0]), self.nbins)
        cls_loss = cls_loss_fn(cls_true, y_pred)
        
        # Calculate MSE Loss
        mse_loss_fn = tf.keras.losses.MeanSquaredError()
        eur_pred = tf.reduce_sum(tf.nn.softmax(y_pred) * self.bin_index, axis=1) * self.degree - self.angle_range
        mse_loss = mse_loss_fn(y_true, eur_pred)
        
        # Total Loss
        total_loss = cls_loss + self.alpha * mse_loss
        
        return total_loss

    
# Define Feature Extractor Layers
class FeatureExtractor(tf.keras.layers.Layer):
    def __init__(self, input_shape=(224, 224, 3), dropout_rate=0.2, num_trainable_layers=None):
        super(FeatureExtractor, self).__init__()
        
        # Define Feature Extractor Model without Dense(Classification) Layers
        self.feature_extractor = EfficientNetB0(include_top=False, input_shape=input_shape, drop_connect_rate=dropout_rate)
        
        # Set Trainable Weights
        if num_trainable_layers is None:
            for layer in self.feature_extractor.layers:
                layer.trainable = False
        else:
            for layer in self.feature_extractor.layers[:-num_trainable_layers]:
                layer.trainable = False
            for layer in self.feature_extractor.layers[-num_trainable_layers:]:
                # print(layer.name)
                if isinstance(layer, BatchNormalization):
                    layer.trainable = False

        
    def call(self, inputs):
        return self.feature_extractor(inputs)

# Define Model Architecture
class HeadPoseNet(tf.keras.Model):
    
    def __init__(self, input_shape=(224,224,3), nbins=66, modelname='HeadPoseNet', num_trainable_layers=None, **kwargs):
        super(HeadPoseNet, self).__init__()
        self.modelname         = modelname
        self.raw_shape         = input_shape
        self.feature_extractor = FeatureExtractor(input_shape, 0.5, num_trainable_layers)

        self.merge             = GlobalAveragePooling2D(name='Pooling')
        # self.bn                = BatchNormalization(name='BatchNorm')
        # self.drop              = Dropout(0.5, name='Dropout')
        
        self.pitch_euler       = Dense(units=nbins, name='Pitch_Output')
        self.yaw_euler         = Dense(units=nbins, name='Yaw_Output')
        self.roll_euler        = Dense(units=nbins, name='Roll_Output')
        self.feature_extractor._name = 'EfficientNetB0'
        
    def call(self, input_tensor):
        x = self.feature_extractor(input_tensor)
        x = self.merge(x)
        # x = self.bn(x)
        # x = self.drop(x)
        
        pitch     = self.pitch_euler(x)
        yaw       = self.yaw_euler(x)
        roll      = self.roll_euler(x)
        
        return {'Pitch':pitch, 'Yaw':yaw, 'Roll':roll}
        
    def build_graph(self):
        x = tf.keras.layers.Input(shape=self.raw_shape, name='Input')
        return Model(inputs=x, outputs=self.call(x), name=self.modelname)

# %% [markdown]
# ## Initialization

# %%
# Head Pose Model Parameters
nbins = 66
angle_range = 99
input_width = 224
input_height = 224
channel = 3

# Model Initialization
model_name = 'HPN_EfficientNetB0_300wlp_v2'
img_shape  = (input_height, input_width, 3)
hpn        = HeadPoseNet(input_shape=img_shape, nbins=nbins, modelname=model_name, num_trainable_layers=16)
hpn_go     = HeadPoseNet(input_shape=img_shape, nbins=nbins, modelname=model_name, num_trainable_layers=16)


# Model Compile
losses = {'Pitch': custom_loss(nbins=nbins, angle_range=angle_range, alpha=1),
          'Yaw': custom_loss(nbins=nbins, angle_range=angle_range, alpha=1),
          'Roll': custom_loss(nbins=nbins, angle_range=angle_range, alpha=1)}
optmz  = tf.keras.optimizers.RMSprop()
hpn.compile(loss=losses, optimizer=optmz)
hpn.build_graph()
hpn_go.compile(loss=losses, optimizer=optmz)
hpn_go.build_graph()

# Filepaths for callbacks
weight_path = pathlib.Path('Training\\weight')
weight_path.mkdir(parents=True, exist_ok=True) 
weight_file = os.path.join(weight_path, model_name + ".hdf5")
log_path    = pathlib.Path('Training\\log')
log_path.mkdir(parents=True, exist_ok=True) 
log_file    = os.path.join(log_path, model_name + '.csv')

# Checkpoint
checkpoint      = ModelCheckpoint(weight_file, 
                                  monitor           = 'val_loss',
                                  mode              = 'min',
                                  save_weights_only = True,
                                  save_best_only    = True,
                                  verbose           = 0)
# Training Logger
csv_logger      = CSVLogger(log_file)   

def lrSchedule(epoch):
    lr = 1e-3
    if epoch > 25:
        lr = 5e-4
    if epoch > 30:
        lr = 1e-4
    if epoch > 80:
        lr = 8e-5
    print('Learning rate: ', lr)
    return lr
LRScheduler = LearningRateScheduler(lrSchedule)

# Model Callback Lists
callbacks_list  = [checkpoint, csv_logger, LRScheduler]                                     

# Model Setup Summary
hpn.build_graph().summary()
print("Path to model :", weight_file)
print("Path to log   :", log_file)
# Out:
# Model: "HPN_EfficientNetB0_300wlp_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# EfficientNetB0 (FeatureExtracto (None, 7, 7, 1280)   4049571     Input[0][0]
# __________________________________________________________________________________________________
# Pooling (GlobalAveragePooling2D (None, 1280)         0           EfficientNetB0[1][0]
# __________________________________________________________________________________________________
# Pitch_Output (Dense)            (None, 66)           84546       Pooling[1][0]
# __________________________________________________________________________________________________
# Roll_Output (Dense)             (None, 66)           84546       Pooling[1][0]
# __________________________________________________________________________________________________
# Yaw_Output (Dense)              (None, 66)           84546       Pooling[1][0]
# ==================================================================================================
# Total params: 4,303,209
# Trainable params: 1,375,222
# Non-trainable params: 2,927,987
# __________________________________________________________________________________________________
# Path to model : Training\weight\HPN_EfficientNetB0_300wlp_v2.hdf5
# Path to log   : Training\log\HPN_EfficientNetB0_300wlp_v2.csv

# %% [markdown]
# ## Model Fitting

# %%
# Training Parameters
num_epoch = 50
batch_size = 50
shuffle = True

# Initialize Data Generators
train_data = data_gen(img_list, eur_list, train_idx, batch_size=batch_size, resize_nrow=input_height, resize_nclm=input_width, shuffle=shuffle)
test_data = data_gen(img_list, eur_list, test_idx, batch_size=batch_size, resize_nrow=input_height, resize_nclm=input_width, shuffle=shuffle)

st = time.time()
# Train Model
hpn_fit = hpn.fit(train_data, validation_data=test_data, epochs=num_epoch, callbacks=callbacks_list)

time_taken = round((time.time() - st)/60,2)

print('Total training time : {0:0.2f} minutes'.format(time_taken))
# Out:
# Epoch 1/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 209s 119ms/step - loss: 293.2010 - Pitch_loss: 88.6559 - Roll_loss: 86.1343 - Yaw_loss: 118.4110 - val_loss: 141.1402 - val_Pitch_loss: 58.9864 - val_Roll_loss: 55.2513 - val_Yaw_loss: 26.9026
# Epoch 2/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 173s 101ms/step - loss: 151.0691 - Pitch_loss: 64.1017 - Roll_loss: 59.7181 - Yaw_loss: 27.2492 - val_loss: 126.3656 - val_Pitch_loss: 53.6914 - val_Roll_loss: 50.4968 - val_Yaw_loss: 22.1774oss: 154.0851 - Pitch_loss: 65.2616 - Roll_l - ETA: 1:12 - loss: 154.174 - ETA: 1:02 - loss: 152.7299 - Pitch_loss: 64.5981 - Ro - ETA: 28s - loss: 153.6188 - Pitch_loss: 65.0925 - Roll_loss: 60.8948 - Yaw_l - ETA: 27s - loss: 153.4885 - Pitch_loss: 65.0569 - Roll_lo - ETA: 25s - loss: 153.0948 - Pitch_loss: 64.8866 - Roll_ - ETA: 22s - loss: 153.5085 - Pitch_loss: 65.1144 - Roll_loss: 60.8917 -  - ETA: 21s - loss: 153.2059 - Pitch_ - ETA: 17s - loss: 152.5636 - P - E - ETA: 5s - loss: 151.3 - ETA: 2s - loss: 151.2845 - Pitch_loss: 64.1967 - Roll_loss: 59.8183 - Yaw_l - ETA: 2s - loss: 151.2158 - Pitch_loss: 64.1773  - ETA: 0s - loss: 151.3364 - Pitch_loss: 64.2339 - Roll_loss: 5
# Epoch 3/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 188s 110ms/step - loss: 137.7115 - Pitch_loss: 58.7835 - Roll_loss: 54.0563 - Yaw_loss: 24.8716 - val_loss: 144.8159 - val_Pitch_loss: 56.6262 - val_Roll_loss: 60.0108 - val_Yaw_loss: 28.1789 Pitch_loss: 58.
# Epoch 4/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 197s 115ms/step - loss: 130.4650 - Pitch_loss: 55.0424 - Roll_loss: 50.8166 - Yaw_loss: 24.6061 - val_loss: 124.6482 - val_Pitch_loss: 51.9562 - val_Roll_loss: 49.8885 - val_Yaw_loss: 22.803631.1674 - Pitch_loss: 55.2753 - Roll_loss: 51.0 - ETA: 30s - loss: 131.2223 - Pitch - ETA: 25s - loss: 131.0501 - Pitch_loss: 55.2273 - Roll_loss: 51.044 - ETA: 23s - loss: 130.9711 - Pitch_loss: 55.1862 - Roll_loss: 51.0222 - Yaw_loss: 24.7 - ETA: 23s - loss: 130.9341 - Pitch_loss: 55.1641 - Roll_loss: 51.0095 - Yaw_ - ETA: 22s - loss: 130.7723 - Pitch_loss: 55.0677 - Roll - ETA: 19s - loss: 130.6472 - Pitch_loss: 55.0270 - Roll_loss:  - ETA: 17s - loss: 130.4496 - Pitch_loss: 54.9447 - Roll_loss: 50.8048 - Y - ETA: 15s - loss: 130.2288 - Pitch_loss: 54.8555 - Roll_loss: 50.6850 -  - ETA: 14s - loss: 130.1416 - Pitch_loss: 54.8163 - Roll_loss: 50.6431 - Yaw_loss: 2 - ETA: 13s - loss: 130.0466 - Pitch_loss: 54.7500 - Roll_loss:  - ETA: 11s - loss: 130.2788 - Pitch_loss: 54.8840 - Roll_loss: 50.7489 - Ya - ETA: 10s - loss: 130.3
# Epoch 5/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 189s 110ms/step - loss: 126.0821 - Pitch_loss: 53.1471 - Roll_loss: 49.0495 - Yaw_loss: 23.8855 - val_loss: 117.1612 - val_Pitch_loss: 48.5342 - val_Roll_loss: 45.0023 - val_Yaw_loss: 23.6246406 -
# Epoch 6/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 187s 109ms/step - loss: 123.8612 - Pitch_loss: 51.5284 - Roll_loss: 47.5180 - Yaw_loss: 24.8147 - val_loss: 118.9580 - val_Pitch_loss: 48.4033 - val_Roll_loss: 48.2486 - val_Yaw_loss: 22.3061- loss: 123.7037 - Pitch_loss: 51
# Epoch 7/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 210s 122ms/step - loss: 121.2504 - Pitch_loss: 50.5538 - Roll_loss: 46.7364 - Yaw_loss: 23.9601 - val_loss: 117.7671 - val_Pitch_loss: 49.3487 - val_Roll_loss: 46.4708 - val_Yaw_loss: 21.9477
# Epoch 8/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 217s 127ms/step - loss: 118.7413 - Pitch_loss: 49.1739 - Roll_loss: 45.6626 - Yaw_loss: 23.9048 - val_loss: 120.9421 - val_Pitch_loss: 49.9338 - val_Roll_loss: 47.9435 - val_Yaw_loss: 23.0648
# Epoch 9/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 230s 134ms/step - loss: 119.2681 - Pitch_loss: 49.1532 - Roll_loss: 45.9250 - Yaw_loss: 24.1899 - val_loss: 116.1748 - val_Pitch_loss: 48.6591 - val_Roll_loss: 45.8144 - val_Yaw_loss: 21.7013
# Epoch 10/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 176s 102ms/step - loss: 118.0101 - Pitch_loss: 48.5843 - Roll_loss: 45.3511 - Yaw_loss: 24.0748 - val_loss: 116.1052 - val_Pitch_loss: 46.6955 - val_Roll_loss: 46.6853 - val_Yaw_loss: 22.7244
# Epoch 11/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 179s 104ms/step - loss: 115.8273 - Pitch_loss: 47.4774 - Roll_loss: 44.9798 - Yaw_loss: 23.3701 - val_loss: 115.7039 - val_Pitch_loss: 47.2681 - val_Roll_loss: 47.1108 - val_Yaw_loss: 21.3251Pitch_loss: 46.4683 - Roll_loss: 43.8605 - Y - ETA: 57s - loss: 113.2433 - Pit - ETA: 2s - loss: 115.828
# Epoch 12/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 179s 105ms/step - loss: 114.5519 - Pitch_loss: 46.4635 - Roll_loss: 44.1887 - Yaw_loss: 23.8999 - val_loss: 122.5431 - val_Pitch_loss: 50.7312 - val_Roll_loss: 49.9178 - val_Yaw_loss: 21.8942 - Pitch_loss: 46.6806 - Roll_loss: - ETA: 44s - loss: 113.5898 - Pitch_loss: 46.5022 - R
# Epoch 13/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 168s 98ms/step - loss: 118.2149 - Pitch_loss: 47.9508 - Roll_loss: 44.8457 - Yaw_loss: 25.4183 - val_loss: 134.6040 - val_Pitch_loss: 62.3910 - val_Roll_loss: 48.6509 - val_Yaw_loss: 23.5620- loss: 116.9724 - Pitch_loss: 48.5935 - Roll_los - ETA: 1:00 - loss: 117.5052 - Pitch_loss: 48.52 - ETA: 31s - loss: 117.4400 - Pitch_loss: 47.7488 - Roll_loss: 44.2621 - Yaw_loss: 25.42 - ETA: 31s - loss: 117.4005 - Pitch_loss: 47.7215 - - ETA: 16s - loss: 11 - ETA: 1s - loss: 118.2035 - Pitch_loss: 47.9493 - Ro - ETA: 0s - loss: 118.2101 - Pitch_loss: 47.9434 - Roll_loss: 44.8441 - Yaw_los
# Epoch 14/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 175s 102ms/step - loss: 118.4321 - Pitch_loss: 46.7178 - Roll_loss: 46.0701 - Yaw_loss: 25.6443 - val_loss: 114.5928 - val_Pitch_loss: 47.9935 - val_Roll_loss: 45.1555 - val_Yaw_loss: 21.4438 - loss:  - ETA: 15s - loss: 118.9051 - Pitch_loss: 46.5978 - Roll_loss: 46.1194 - Yaw_loss: - ETA: 14s - loss
# Epoch 15/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 205s 120ms/step - loss: 115.5515 - Pitch_loss: 47.3346 - Roll_loss: 44.4545 - Yaw_loss: 23.7623 - val_loss: 126.1828 - val_Pitch_loss: 52.9770 - val_Roll_loss: 52.0105 - val_Yaw_loss: 21.1954
# Epoch 16/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 177s 103ms/step - loss: 114.5761 - Pitch_loss: 45.3793 - Roll_loss: 43.5311 - Yaw_loss: 25.6658 - val_loss: 121.4010 - val_Pitch_loss: 51.7782 - val_Roll_loss: 49.0452 - val_Yaw_loss: 20.5776: 47s - loss: 112.3474 - Pitch_loss: 44.7036 - Roll_loss: 42.7333  - ETA: 46s - loss: 112.2409 - Pitch_loss: 44.6515 - Roll_loss: 42.7379 -  - ETA: 45s - loss: 11 - ETA: 40s - loss: 112.6040 - Pitch_loss: 44.7887 - Roll_loss: 42.8675 - Yaw_loss: - ETA: 39s - loss: 112.6930 - Pitch_loss: 44.8314 -  - ETA: 36s - loss: 113.1903 - Pitch_loss: 44.9765 - Ro - ETA: 34s - loss: 113.2561 - Pitch_loss: 45.0704 - Roll_loss: 43.1223 - Y - ETA: 26s - loss: 113.5893 - Pitch_loss: 45.2400 - Roll_loss: 43.1 - ETA: 24s - loss: 113.6975 - Pitch_loss: 45.3296 - Roll_loss: 43.18  - ETA: 11s - loss: 114.81 - ETA:  - ETA: 1s - loss: 114.7860 - Pitc
# Epoch 17/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 191s 111ms/step - loss: 114.0363 - Pitch_loss: 46.1400 - Roll_loss: 44.1659 - Yaw_loss: 23.7306 - val_loss: 113.4128 - val_Pitch_loss: 47.0733 - val_Roll_loss: 46.0129 - val_Yaw_loss: 20.3265
# Epoch 18/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 182s 106ms/step - loss: 115.6845 - Pitch_loss: 46.0162 - Roll_loss: 43.3651 - Yaw_loss: 26.3033 - val_loss: 120.0722 - val_Pitch_loss: 49.7607 - val_Roll_loss: 48.5210 - val_Yaw_loss: 21.7905- ETA: 53s - loss: 116.85 - ETA: 48s - loss: 115.9753 - Pitch_loss: 45.6322 - R - ETA: 45s - loss: 115.5272 - Pit - ETA: 41s - loss: 115.1334 - Pitch_loss: 45.2095 - - ETA: 18s - loss: 115.7561 - Pitch_loss: 45.9675 - Roll_loss: 43.0597 - Yaw_loss: 26. - ETA: 17s - loss: 115.8865 - Pitch_loss: 46.0250 - Roll_loss: 43.1418 - Ya - ETA: 16s - loss: 115.7239 - Pitch_loss: 45.9676 - Roll_loss: 43.0770 - - ETA: 15s - loss: 115.6601 - Pitch - ETA: 3s - loss: 115.169 - ETA: 1s - loss: 115.5477 - Pitch_loss: 45.915
# Epoch 19/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 179s 105ms/step - loss: 116.2082 - Pitch_loss: 46.1560 - Roll_loss: 44.4301 - Yaw_loss: 25.6222 - val_loss: 122.0684 - val_Pitch_loss: 47.6823 - val_Roll_loss: 48.9627 - val_Yaw_loss: 25.4235_los - ETA: 1:00 - loss: - ETA: 28s - loss: 114.7243 - Pitch_loss: 45.9375 - Roll_loss:  - ETA: 26s - loss: 114.6750 - Pitch_loss: 45.9462 - Roll_lo
# Epoch 20/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 193s 113ms/step - loss: 116.8756 - Pitch_loss: 45.9668 - Roll_loss: 44.8380 - Yaw_loss: 26.0707 - val_loss: 118.2402 - val_Pitch_loss: 50.1666 - val_Roll_loss: 48.8117 - val_Yaw_loss: 19.2620
# Epoch 21/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 204s 119ms/step - loss: 118.2383 - Pitch_loss: 46.4210 - Roll_loss: 44.6363 - Yaw_loss: 27.1810 - val_loss: 122.3835 - val_Pitch_loss: 49.2934 - val_Roll_loss: 51.3980 - val_Yaw_loss: 21.6922
# Epoch 22/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 190s 111ms/step - loss: 117.1614 - Pitch_loss: 46.1854 - Roll_loss: 45.4238 - Yaw_loss: 25.5522 - val_loss: 128.0469 - val_Pitch_loss: 52.3232 - val_Roll_loss: 49.0315 - val_Yaw_loss: 26.6922
# Epoch 23/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 196s 115ms/step - loss: 118.1309 - Pitch_loss: 46.0762 - Roll_loss: 45.3208 - Yaw_loss: 26.7338 - val_loss: 130.6827 - val_Pitch_loss: 59.2505 - val_Roll_loss: 51.4117 - val_Yaw_loss: 20.0205
# Epoch 24/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 203s 119ms/step - loss: 120.7019 - Pitch_loss: 47.3138 - Roll_loss: 46.1367 - Yaw_loss: 27.2514 - val_loss: 117.9762 - val_Pitch_loss: 48.3032 - val_Roll_loss: 48.1886 - val_Yaw_loss: 21.48437.0679 -  - ETA: 0s - loss: 120.7192 - Pitch_loss: 47.3214 - Roll_loss: 46.1441 - Yaw_loss: 27.
# Epoch 25/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 220s 129ms/step - loss: 126.1608 - Pitch_loss: 47.4792 - Roll_loss: 46.4029 - Yaw_loss: 32.2787 - val_loss: 120.9008 - val_Pitch_loss: 49.7645 - val_Roll_loss: 50.0985 - val_Yaw_loss: 21.0379: 47 - ETA: 15s - loss: 125.5392 - Pitch_loss: 46.9722 - Roll_loss: 45.9842 - Yaw_lo - ETA: 14s - loss: 125.4357 - Pitch_loss: 46.9477 - Roll_loss: 45.96 - ETA: 12s - loss: 125.1380 - Pitch_loss: 46.8684 - Roll_loss: 45.8758 - Yaw_loss - ETA: 11s - loss: 125.0960 - ETA: 3s
# Epoch 26/50
# Learning rate:  0.001
# 1714/1714 [==============================] - 227s 133ms/step - loss: 123.2472 - Pitch_loss: 47.5424 - Roll_loss: 46.5700 - Yaw_loss: 29.1348 - val_loss: 123.5990 - val_Pitch_loss: 51.3041 - val_Roll_loss: 50.8733 - val_Yaw_loss: 21.4217
# Epoch 27/50
# Learning rate:  0.0005
# 1714/1714 [==============================] - 250s 146ms/step - loss: 103.0642 - Pitch_loss: 41.4373 - Roll_loss: 39.4586 - Yaw_loss: 22.1682 - val_loss: 111.1204 - val_Pitch_loss: 45.3595 - val_Roll_loss: 45.1340 - val_Yaw_loss: 20.6270
# Epoch 28/50
# Learning rate:  0.0005
# 1714/1714 [==============================] - 208s 121ms/step - loss: 99.6052 - Pitch_loss: 39.3909 - Roll_loss: 37.7330 - Yaw_loss: 22.4814 - val_loss: 116.4634 - val_Pitch_loss: 49.4096 - val_Roll_loss: 45.3207 - val_Yaw_loss: 21.7331
# Epoch 29/50
# Learning rate:  0.0005
# 1714/1714 [==============================] - 173s 101ms/step - loss: 97.6040 - Pitch_loss: 39.2619 - Roll_loss: 36.4797 - Yaw_loss: 21.8625 - val_loss: 110.6083 - val_Pitch_loss: 45.4843 - val_Roll_loss: 45.7713 - val_Yaw_loss: 19.35278.8612 - Pitch_loss: 40.4201 - Roll_loss: 37.3260 - Yaw_los - ETA: 1:55 - loss: 98.2049 - Pitch_loss: 40.0740 - Roll_loss: 37.0056 - Yaw_loss - ETA: 1:54 - loss:  - ETA: 1:45 - loss: 99.4303 - ETA: 1:31 - loss: 99.9380 - Pitch_loss: 40.7353 - Roll_loss: 37.9303 - Y - ETA: 1:30 - loss: 99.4215 - Pitch_loss: 40.4558 - Roll_loss: 37.7152 - Yaw_loss: - ETA: 14s - loss: 96.7170 - - ETA: 8s - loss: 96.6720 - Pitch_loss: 39.0442 - Roll_loss: 36.1698 - Yaw_ - ETA: 7s - loss: 96.6918 - Pitch_loss: 39.0346 - Roll_loss: 36.1 - ETA: 5s - loss: 97.3587 - Pitch_loss: 39.1990 - Roll_loss: 36.2798  - ETA: 4s - loss: 97
# Epoch 30/50
# Learning rate:  0.0005
# 1714/1714 [==============================] - 173s 101ms/step - loss: 98.5238 - Pitch_loss: 38.3059 - Roll_loss: 37.3230 - Yaw_loss: 22.8948 - val_loss: 109.4282 - val_Pitch_loss: 44.7429 - val_Roll_loss: 44.1878 - val_Yaw_loss: 20.4975
# Epoch 31/50
# Learning rate:  0.0005
# 1714/1714 [==============================] - 167s 97ms/step - loss: 96.5517 - Pitch_loss: 38.1676 - Roll_loss: 36.4898 - Yaw_loss: 21.8943 - val_loss: 108.2785 - val_Pitch_loss: 44.1135 - val_Roll_loss: 44.5010 - val_Yaw_loss: 19.6640- ETA: 8s - loss: 96.6406 - Pitch_loss: 38.4004 - Roll_loss: 36.5114 - - ETA: 7s - loss: 96.8835 - Pitch_loss: 38.4 - ETA: 4s - loss: 96.8533 - Pitch_loss:  - ETA: 1s - loss: 96.6762 - Pitch_loss: 38.2145 - Roll_loss: 36.5594 - Yaw_loss: - ETA: 0s - loss: 96.6278 - Pitch_loss: 38.1980 - Roll_loss: 36.5339 - Yaw_loss
# Epoch 32/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 172s 100ms/step - loss: 87.9383 - Pitch_loss: 34.7199 - Roll_loss: 32.4359 - Yaw_loss: 20.7826 - val_loss: 103.0626 - val_Pitch_loss: 42.2902 - val_Roll_loss: 41.6407 - val_Yaw_loss: 19.1317 89.3130 - Pitch_loss - ETA: 1:34 - loss: 88.2664 - Pitch_loss: 33.7237 - Roll_loss: 32.9166 - Yaw_loss: 21.626 - ETA: 1:34 - loss: 88.2264 - Pitch_loss: 33.7106 - Roll_loss: 32.8940 - Yaw_loss: 21.621 - ETA: 1:34 - loss: 88.1567 - Pitch_loss: 33.6912 - Roll_loss: 32.8497 - Yaw - ETA: 1:33 - loss: 87.7860 - Pitch_loss: 33.5431 - R - ETA: 1:24 -  - ETA: 16s - loss: 87.7743 - Pitch_loss:  - ETA: 14s - loss: 87.7694 - Pit - ETA: 8s - loss: 88.0611 - Pitch_loss: 34.7623 - Roll_lo -
# Epoch 33/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 171s 100ms/step - loss: 86.0837 - Pitch_loss: 34.1577 - Roll_loss: 31.3987 - Yaw_loss: 20.5273 - val_loss: 102.4531 - val_Pitch_loss: 42.4332 - val_Roll_loss: 40.9113 - val_Yaw_loss: 19.1087 85.1211 - Pitch_loss: 33.7874 - Roll_loss: 31.0952 - ETA: 5s - loss: 85.0128 - Pitch_loss: 33.7255 - Roll_loss: 31.0535 - Yaw_loss: 20 - ETA: 5s - loss: 85.3164 - Pitch_loss: 33.7163 - Roll_loss: 31.040 - ETA: 3s - loss: 85.5170 - Pitch_
# Epoch 34/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 177s 104ms/step - loss: 85.4111 - Pitch_loss: 33.7206 - Roll_loss: 30.9531 - Yaw_loss: 20.7373 - val_loss: 101.7334 - val_Pitch_loss: 41.4220 - val_Roll_loss: 40.5792 - val_Yaw_loss: 19.732297 - Roll_loss: - ETA: 3s - loss: 85.5269 - Pitch_loss: 33.7950 - Roll_loss: 30.9819 - Yaw_loss:  - ETA: 3s - loss: 85.4928 - Pitch_loss: 3
# Epoch 35/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 175s 102ms/step - loss: 84.6814 - Pitch_loss: 33.4136 - Roll_loss: 30.6847 - Yaw_loss: 20.5830 - val_loss: 102.8830 - val_Pitch_loss: 42.5371 - val_Roll_loss: 40.7239 - val_Yaw_loss: 19.6221- Pitch_loss: 34.2887 - Roll_loss: 30.7411 - Yaw_l - ETA: 1:42 - loss:  - ETA: 1:38 - loss: 85.5888 - Pitch_loss: 33.8850 -  - ETA: 1:35 - loss: 91.4359 - Pitch_loss: 36.7614 - Roll_loss: 34.0010 - Ya - ETA: 1:34 - loss: 90.3531 - Pitch_loss: 36.2538 - Rol - ETA: 1:32 - loss: - ETA: 54s - loss: 85.5722 - Pitch_ - ETA: 52s - loss: 85.2692 - Pitch_loss: 33.5278 - Roll_los - ETA: 51s - loss: 85.1368 - Pitch_loss: 33.4573 - Roll_loss: 30.9043 - ETA: 51s - loss: 85.0700 - Pitch_loss: 33.4013 -  - ETA: 7s - loss: 84.5507 - P - ETA: 3s - loss: 84.6692 - Pitch_loss: 33.4030 - Roll_loss: 30.6781 - Y - ETA: 2s - loss: 84.5605 - Pitch_loss: 33.3459 - Roll_loss: 30.629 - ETA: 0s - loss: 84.6369 - Pitch_loss: 33.3895 - Roll_loss: 30.6620 - Yaw_lo
# Epoch 36/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 201s 117ms/step - loss: 83.7761 - Pitch_loss: 33.1249 - Roll_loss: 30.3647 - Yaw_loss: 20.2865 - val_loss: 102.2502 - val_Pitch_loss: 41.6117 - val_Roll_loss: 41.1137 - val_Yaw_loss: 19.5250
# Epoch 37/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 202s 118ms/step - loss: 83.8350 - Pitch_loss: 32.6590 - Roll_loss: 30.3600 - Yaw_loss: 20.8159 - val_loss: 102.3487 - val_Pitch_loss: 42.3752 - val_Roll_loss: 40.3935 - val_Yaw_loss: 19.5801
# Epoch 38/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 185s 108ms/step - loss: 82.5080 - Pitch_loss: 32.5784 - Roll_loss: 29.8861 - Yaw_loss: 20.0434 - val_loss: 101.8738 - val_Pitch_loss: 41.8025 - val_Roll_loss: 40.4698 - val_Yaw_loss: 19.60164005 - Pitch_loss: 32.5285 - Roll_loss: 28.9076 - Yaw_loss: 19. - ETA: 2:15 - loss: 81.4635 - Pitch_loss: 32.5313 - Roll_l - ETA: 2:08 - loss: 81.6872 - Pitch_loss: 32.4715 - ETA: 2:00 - loss: 80.7026 - Pitch_loss: 32.0108 - Roll_loss: 28.7615 - Yaw_loss: 19.93 - ETA: 2:00 - loss: 80.6417 - Pitch_loss: 31.9616 - Roll_los
# Epoch 39/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 244s 143ms/step - loss: 82.3012 - Pitch_loss: 32.2737 - Roll_loss: 29.9400 - Yaw_loss: 20.0875 - val_loss: 101.3524 - val_Pitch_loss: 41.6344 - val_Roll_loss: 40.3678 - val_Yaw_loss: 19.35025 - Pitch_loss: 32.2061 - Roll_loss: 29.991 - ETA: 6s - loss:
# Epoch 40/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 229s 133ms/step - loss: 81.9760 - Pitch_loss: 32.1143 - Roll_loss: 29.5082 - Yaw_loss: 20.3534 - val_loss: 100.8228 - val_Pitch_loss: 40.8973 - val_Roll_loss: 40.2433 - val_Yaw_loss: 19.6822
# Epoch 41/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 246s 143ms/step - loss: 81.8148 - Pitch_loss: 31.9596 - Roll_loss: 29.5967 - Yaw_loss: 20.2586 - val_loss: 101.0611 - val_Pitch_loss: 41.1635 - val_Roll_loss: 40.2172 - val_Yaw_loss: 19.6806
# Epoch 42/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 241s 141ms/step - loss: 82.2440 - Pitch_loss: 31.7577 - Roll_loss: 29.5783 - Yaw_loss: 20.9079 - val_loss: 103.1592 - val_Pitch_loss: 42.3199 - val_Roll_loss: 41.6396 - val_Yaw_loss: 19.1997
# Epoch 43/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 189s 110ms/step - loss: 80.8884 - Pitch_loss: 31.5537 - Roll_loss: 29.3454 - Yaw_loss: 19.9892 - val_loss: 103.7341 - val_Pitch_loss: 41.7088 - val_Roll_loss: 42.7213 - val_Yaw_loss: 19.3040.2143 - Pitch_loss: 33.2516 - Roll_loss: 29.8586 - Yaw_loss: 20. - ETA: 2:28 - loss: 83.3450 - Pitch_loss: 33 - ETA: 2:16 - loss: 83.1076 - Pitch_loss: 33.0851 - Rol - ETA: 1:40 - loss: 81.5472 - Pitch_loss: 32.0966 - Roll_loss: 29.3791 - Yaw_lo - ETA:  - ETA: 1:33 - loss: 81.2607 - Pitch_loss: 31.6710 - Roll_loss: 29.5451 - Yaw_loss: 2 - ETA: 1:32 - loss: 81.1414 - Pitch_loss: 31.6128 - Roll_loss: 29. - ETA: 1:29 - loss: 80.9287 - Pitch_loss: 31.4765 - Roll_loss: 29.4094 - Yaw_ - ETA: 1:27 - loss: 81.0192 - Pitch_loss: 31.5101 - Roll_loss: 29.4715 - Yaw_los - ETA: 1:26 - loss: 80 - ETA: 12s - loss: 80.2506 - Pitch_loss: 31.2559 - Roll_loss: 28.9999 - Yaw_loss: 19. - ETA: 12s - ETA: 9s - loss: 80.2585 - Pitch_loss: 31.2460 - Roll_loss: - ETA: 6s - loss: 80.3926 - Pitch_loss: 31.2932 - ETA: 3s - loss: 80.5702 - Pitch_loss: 31.4058 - Roll_los - ETA: 1s - loss: 80.7289 - Pitch_loss: 31.4553 - Roll_loss: 29.2831 - Yaw
# Epoch 44/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 178s 104ms/step - loss: 80.8235 - Pitch_loss: 31.4284 - Roll_loss: 29.0219 - Yaw_loss: 20.3731 - val_loss: 100.7800 - val_Pitch_loss: 40.9517 - val_Roll_loss: 40.0302 - val_Yaw_loss: 19.7981h_loss: 31.6358 - Roll_loss: 29.252 - ETA: 1:38 - loss: 80.3311 - Pitch_loss: 31.23 - ETA: 1:36 - loss: 80. - ETA: 1:18 - loss: 81.3519 - Pitch_loss: 31.1534 - Roll_loss: 29.0937  - ETA: 1:17 - loss: 81.1772 - Pitch_loss: 31. - ETA: 1:14 - loss: 80.8917 - Pitch_loss: 30.9241 - Roll_loss: 28.9544 - Yaw_loss: 21.013 - ETA: 1:14 - loss: 80.8713 - Pitch_loss: 30.9150 - Roll_loss: 28.9438 - Yaw_loss: 21. - ETA: 1:14 - loss: 80.8021 - Pitch_loss: 30.8760 - Roll_loss: 28.9221 - ETA: 1:12 - loss: 80.7343 - Pitch_loss: 30.8517 - Roll_loss: 28.8986  - ETA: 1:11 - loss: 80.4703 - Pitch_loss: 30. - ETA: 1:06 - loss: 80.9303 - Pitch_loss: 3 - ETA: 22s - loss: 80.9378 - Pitch_loss: 31.3 - ETA: 20s - loss: 80.8163 - Pitch_ - ETA: 15s - loss: 80.5814 - Pitch_loss:  - ETA: 10s - loss - ETA: 6s - loss: 80.3130 - Pitch_loss: 31.1250 - Roll_loss: 28.7940 - Yaw_loss: - ETA: 5s - loss: 80.4148 - Pitch_loss: 31.1655 - Roll_loss: 28.8605 - Ya - ETA: 4s - loss: 80.5247 - Pitch_loss: 3 - ETA: 1s - loss: 80.7030 - Pitch_loss: 31.3407 - Roll_loss: 28.9848 - - ETA: 0s - loss: 80.8473 - Pitch_loss: 31.4386 - Roll_loss: 29.0366 - Yaw_loss: 20.
# Epoch 45/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 200s 117ms/step - loss: 80.7996 - Pitch_loss: 31.4463 - Roll_loss: 28.9637 - Yaw_loss: 20.3895 - val_loss: 100.6401 - val_Pitch_loss: 40.7001 - val_Roll_loss: 40.4481 - val_Yaw_loss: 19.492003 - Roll_loss: 26.7617 - Y -  - ETA: 1:47 - loss: 78.1388 - Pitch_loss: 30.2624 - Rol - ETA: 1:44 - loss: 77.9187 - Pitch_loss: 30.1889 - Roll_loss: 27.8299 - Yaw_ - ETA: 1:43 - loss: 78.5950 - Pitch_loss: 30.4159 - Roll_loss: 28.2666 - Yaw_ - ETA: 1:42 - loss: 77.9341 - Pitch_loss: 30.1017 - Roll_loss: 27.9354 - - ETA: 1:41 - loss: 79.7061 -  - ETA: 1:37 - loss: 80.8285 - Pitch_loss: 31. - ETA: 1:22 - loss: 80.3983 - Pitch_loss: 31.0307 - Roll_loss: 28.8322 - Yaw_ - ETA: 1:21 - loss: 80.2246 - Pitch_loss: 30.979 - ETA: 1:18 - loss: 80.1899 - Pitch_loss: 30.9064 - Roll_loss - ETA: 1:16 - loss: 81.0785 - Pitch_loss: 31. - ETA: 1:13 - loss: 81.4958 - Pitch_loss: 31.6669 - Roll_loss: 29.4540 - Yaw_loss: - ETA: 54s - loss: 81.0464 - Pitch_loss: 31.225 - ETA - ETA: 40s - loss: 81.4231 - Pitch_loss: 31.5651 - Ro - ETA: 38s - loss: 81.4822 - Pitch_loss: 31.6141 - Ro - ETA: 37s - loss: 81.4619 - Pitch_loss: 31.6190 - Roll_loss: - ETA: 36s - loss: 81.4678 - Pitch_loss: 31.6136 - Roll_loss: 29.2733 - Yaw - - ETA: 32s - loss: 81.3379 - Pitch_loss: 31.5472 - Roll_loss: 29.2431 - Yaw_loss: 2 - ETA: 32s - loss: 81.3189  - ETA: 30s - loss: 81.2260 - Pitch_loss: 31.4973 - Roll_loss: 29.1980 - Yaw - ETA: 30s - loss: 81.1600 - Pitch_loss: 31.4603 - Roll_loss: 29.1709 - Yaw_loss: 20.52 - ETA: 29s - loss: 81.1690 - Pitch_loss: 31.4670 - Roll_loss: 29.1731 - Yaw_los - ETA: 29s - loss: 81.2007 - Pitch_loss: 31.4940 - Roll_loss: 29.1818 - Y - E - ETA: 26s - loss: 81.0 - ETA: 5s - loss: 80.9467 - Pitch_loss: 31.529 - ETA: 2s - loss: 80.9024 - Pitch_loss: 31.4854
# Epoch 46/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 193s 112ms/step - loss: 80.2681 - Pitch_loss: 31.1894 - Roll_loss: 29.1072 - Yaw_loss: 19.9716 - val_loss: 101.3860 - val_Pitch_loss: 41.0887 - val_Roll_loss: 40.7128 - val_Yaw_loss: 19.5845
# Epoch 47/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 226s 132ms/step - loss: 80.4228 - Pitch_loss: 31.0314 - Roll_loss: 29.0081 - Yaw_loss: 20.3832 - val_loss: 101.6208 - val_Pitch_loss: 41.3297 - val_Roll_loss: 40.7961 - val_Yaw_loss: 19.4951
# Epoch 48/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 193s 112ms/step - loss: 79.7663 - Pitch_loss: 31.0255 - Roll_loss: 28.7026 - Yaw_loss: 20.0383 - val_loss: 100.8921 - val_Pitch_loss: 41.2412 - val_Roll_loss: 40.0803 - val_Yaw_loss: 19.5706s: 30.7062 - ETA: 6s - loss: 79.3212 - Pitch_loss: 30. - ETA: 3s - loss: 79.7956 - Pitch_loss: 31.0358
# Epoch 49/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 199s 116ms/step - loss: 79.5407 - Pitch_loss: 30.8127 - Roll_loss: 28.6159 - Yaw_loss: 20.1120 - val_loss: 101.3207 - val_Pitch_loss: 41.0636 - val_Roll_loss: 40.8238 - val_Yaw_loss: 19.4332
# Epoch 50/50
# Learning rate:  0.0001
# 1714/1714 [==============================] - 195s 114ms/step - loss: 79.5503 - Pitch_loss: 30.5575 - Roll_loss: 28.5298 - Yaw_loss: 20.4630 - val_loss: 101.4349 - val_Pitch_loss: 41.5450 - val_Roll_loss: 40.4205 - val_Yaw_loss: 19.4694
# Total training time : 164.12 minutes

# %% [markdown]
# ## Model Saving

# %%
# SavedModel Path
model_path = pathlib.Path('Training/model')
model_path.mkdir(parents=True, exist_ok=True)
save_model_name = 'HPN_EfficientNetB0_300wlp_v2'
model_file = os.path.join(model_path, save_model_name)

# Save Model Architecture and Weights to File
hpn_go.compile(loss=losses, optimizer=optmz)
hpn_go.compute_output_shape(input_shape=(None, *img_shape))
hpn_go.load_weights(weight_file)
hpn_go.save(model_file, save_format='tf')
# Out:
# INFO:tensorflow:Assets written to: Training\model\HPN_EfficientNetB0_300wlp_v2\assets
# C:\Users\JMLim\anaconda3\envs\py39_gpu1\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %% [markdown]
# # 3. Model Evaluation

# %% [markdown]
# ## Loss Chart

# %%
# Model Evaluation
hpn_result = pd.DataFrame(hpn_fit.history)

plt.figure(figsize=(27,6))
# Plot Train and Validation Loss
plt.subplot(121)
plt.plot(hpn_result['loss'])
plt.plot(hpn_result['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Model Loss')
plt.legend(['train', 'validation'], loc='upper left')

# %% [markdown]
# ## Load Model

# %%
# SavedModel Path
model_path = pathlib.Path('Training/model')
model_path.mkdir(parents=True, exist_ok=True)
load_model_name = 'HPN_EfficientNetB0_300wlp_v2'
model_file = os.path.join(model_path, load_model_name)

# Load Model Architecture and Weights
hpn_go.compile(loss=losses, optimizer=optmz)
hpn_go.compute_output_shape(input_shape=(None, *img_shape))
hpn_go.load_weights(weight_file)

# %% [markdown]
# ## Prediction Function

# %%
# Function to predict euler bins
def hpn_predict_bins(loaded_model, input_tensor):
    pred_bins = loaded_model(input_tensor)
    return pred_bins['Pitch'], pred_bins['Yaw'], pred_bins['Roll']

# Function to calculate predict angle
@tf.function
def derive_eur(pred_bins, bin_index, bin_degree, angle_range):
    pred_eur = tf.reduce_sum(tf.nn.softmax(pred_bins) * bin_index, axis=1) * bin_degree - angle_range
    return pred_eur
    
# Function to calculate total square error (TSE)
@tf.function
def cal_TSE(y_true, y_pred):
    TSE = tf.reduce_sum((y_true - y_pred) ** 2)
    return TSE

# Function to calculate total absolute error (TAE)
@tf.function
def cal_TAE(y_true, y_pred):
    TAE = tf.reduce_sum(tf.math.abs(y_true - y_pred))
    return TAE

# %% [markdown]
# ## Calculate MSE & MAE

# %%
# Initialization
input_width = 224
input_height = 224

count = 0
batch_count = 100

pitch_TSE = 0
yaw_TSE = 0
roll_TSE = 0

pitch_TAE = 0
yaw_TAE = 0
roll_TAE = 0

bin_index = np.array([idx for idx in range(nbins)], dtype=np.float32)
bin_degree = 2 * angle_range / nbins

# num_batch = len(test_img_list) // batch_count + 1
# last_batch_size = len(test_img_list) % batch_count
num_batch = len(test_idx) // batch_count + 1
last_batch_size = len(test_idx) % batch_count

# Load and Calculate Squared Error by batch
for i in range(num_batch):
    batch_idx = np.array(test_idx[i*batch_count : min((i+1)*batch_count, len(test_idx))])
    batch_img_list = np.array(img_list)[batch_idx]
    batch_eur_list = np.array(eur_list)[batch_idx]
    
    batch_img_data = []
    batch_eur_data = []
    # Load image and euler angles
    for i in range(len(batch_idx)):
        # Load image
        img_path = batch_img_list[i]
        load_img = cv2.imread(img_path)
        img = cv2.resize(load_img, (input_width, input_height))
        # Load euler angles
        eur_path = batch_eur_list[i]
        eur_file = open(eur_path, 'r')
        eur = np.array(eur_file.readlines()[0].split(','), dtype=np.float32)[[0,2]] # Only take pitch and roll
        eur_file.close()
        # Appends
        batch_img_data.append(img)
        batch_eur_data.append(eur)
    
    batch_img_data = np.array(batch_img_data)
    batch_eur_data = np.array(batch_eur_data)
    # Bin Prediction
    pitch_bins, yaw_bins, roll_bins = hpn_predict_bins(hpn_go, batch_img_data)
    
    # Euler Prediction
    pitch_eur = derive_eur(pitch_bins, bin_index, bin_degree, angle_range)
    yaw_eur   = derive_eur(yaw_bins, bin_index, bin_degree, angle_range)
    roll_eur  = derive_eur(roll_bins, bin_index, bin_degree, angle_range)
    
    # Calculate TSE
    batch_pitch_TSE = cal_TSE(batch_eur_data[:,0], pitch_eur)
    batch_yaw_TSE   = cal_TSE(batch_eur_data[:,0], yaw_eur)
    batch_roll_TSE  = cal_TSE(batch_eur_data[:,1], roll_eur)
    
    # Calculate TAE
    batch_pitch_TAE = cal_TAE(batch_eur_data[:,0], pitch_eur)
    batch_yaw_TAE   = cal_TAE(batch_eur_data[:,0], yaw_eur)
    batch_roll_TAE  = cal_TAE(batch_eur_data[:,1], roll_eur)
    
    # Append Results
    pitch_TSE += batch_pitch_TSE
    yaw_TSE   += batch_yaw_TSE
    roll_TSE  += batch_roll_TSE
    pitch_TAE += batch_pitch_TAE
    yaw_TAE   += batch_yaw_TAE
    roll_TAE  += batch_roll_TAE
    count     += len(batch_idx)

# Calculate final Stats
pitch_MSE = pitch_TSE.numpy() / count
yaw_MSE   = yaw_TSE.numpy() / count
roll_MSE  = roll_TSE.numpy() / count
pitch_MAE = pitch_TAE.numpy() / count
yaw_MAE   = yaw_TAE.numpy() / count
roll_MAE  = roll_TAE.numpy() / count
avg_MSE   = (pitch_MSE + yaw_MSE + roll_MSE)/3
avg_MAE   = (pitch_MAE + yaw_MAE + roll_MAE)/3

print('==========================================================================')
print('Individual Euler Angle Mean Squared Error (MSE):')
print('------------------------------------------------')
print('Pitch MSE :', str(round(pitch_MSE,3)))
print('Yaw MSE   :', str(round(yaw_MSE,3)))
print('Roll MSE  :', str(round(roll_MSE,3)))
print('==========================================================================')
print('Individual Euler Angle Mean Absolute Error (MAE):')
print('------------------------------------------------')
print('Pitch MAE :', str(round(pitch_MAE,3)))
print('Yaw MAE :', str(round(yaw_MAE,3)))
print('Roll MAE  :', str(round(roll_MAE,3)))
print('==========================================================================')
print('Overall MSE & MAE:')
print('------------------------------------------------')
print('MSE :', str(round(avg_MSE,3)))
print('MAE :', str(round(avg_MAE,3)))
# Out:
# ==========================================================================
# Individual Euler Angle Mean Squared Error (MSE):
# ------------------------------------------------
# Pitch MSE : 24.585
# Yaw MSE   : 3223.755
# Roll MSE  : 24.38
# ==========================================================================
# Individual Euler Angle Mean Absolute Error (MAE):
# ------------------------------------------------
# Pitch MAE : 2.512
# Yaw MAE : 49.631
# Roll MAE  : 2.251
# ==========================================================================
# Overall MSE & MAE:
# ------------------------------------------------
# MSE : 1090.907
# MAE : 18.131
